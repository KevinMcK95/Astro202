# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This is me just testing the $\LaTeX$
#
# It seems to be working well so far!
#
# Notes:
#  - Shift + Tab inside of a function gives the information about the function inputs
#  -Tab while writing a function will show you the list of matching names
#
# I will create a nice plot below:

# %%
x = np.arange(-3*np.pi,3*np.pi,0.01)
y = 2*np.sin(x)+x/5
plt.figure()
plt.plot(x,y)
plt.show()
